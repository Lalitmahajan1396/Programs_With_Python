# %%
##1.	Write a Python program to take two numbers as input from the user and display their sum.

a = float(input("Enter The First Number :"))
b = float(input("Enter The Second Number :"))

sum = a + b

print("The Sum of",a,"and",b,"is:",sum)
# Out:
# Enter The First Number :20
# Enter The Second Number :30
# The Sum of 20.0 and 30.0 is: 50.0

# %%
##2.	Calculate and print the midpoint of two numbers entered by the user.

num1 = float(input("Enter The first Number :"))
num2 = float(input("Enter The Second Number :"))

midpoint=(num1 + num2) /2

print("The midpoint is :",midpoint)
# Out:
# Enter The first Number :20
# Enter The Second Number :30
# The midpoint is : 25.0

# %%
## 3.Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.

base = float(input("Enter the value for base of triangle:"))
height = float(input("Enter the value for height of triangle :"))

area = 0.5 * base * height

print("The area of triangle is :",area)
# Out:
# Enter the value for base of triangle:10
# Enter the value for height of triangle :5
# The area of triangle is : 25.0

# %%
## 4.Take three numbers as input from the user and display their product.

product1 = float(input("Enter the first number :"))
product2 = float(input("Enter the second number :"))
product3 = float(input("Enter the third number :"))

product = product1 * product2 * product3

print("Product is :",product)
# Out:
# Enter the first number :5
# Enter the second number :3
# Enter the third number :6
# Product is : 90.0

# %%
## 5.Take a number as input and display its square and cube.

number = float(input("Enter the number :"))

square = number ** 2
cube = number ** 3

print("the square of number is:",square)
print("the cube of number is :",cube)
# Out:
# Enter the number :4
# the square of number is: 16.0
# the cube of number is : 64.0

# %%
## 6.Take two numbers as input and display their quotient and remainder.

num1 = int(input("enter the first number:(quotient) "))
num2 = int(input("Enter the Second number :(remainder)"))

quotient = num1 // num2 #// gives the quotient (integer division)
remainder = num1 % num2 # % gives the remainder

print("the quotient is :",quotient)
print("the remainder is :",remainder)
# Out:
# enter the first number:(quotient) 17
# Enter the Second number :(remainder)5
# the quotient is : 3
# the remainder is : 2

# %%
## 8.Write a Python program to calculate the area of a rectangle using the formula: area = length * width.

length = float(input("enter the Length of rectangle :"))
width = float(input("enter the width of rectangle :"))

area = length * width

print("Area of rectangle is :",area)
# Out:
# enter the Length of rectangle :8
# enter the width of rectangle :5
# Area of rectangle is : 40.0

# %%
##Take five numbers as input representing marks obtained and total marks Display the percentage.

m1 = float(input("Enter the marks for subject1 :"))
m2 = float(input("Enter the marks for subject2 :"))
m3 = float(input("Enter the marks for subject3 :"))
m4 = float(input("Enter the marks for subject4 :"))
m5 = float(input("Enter the marks for subject5 :"))

total_marks = float(input("enter the total marks :"))

total = m1 + m2 + m3 + m4 + m5

percentage = (total / total_marks) * 100

print("Percentage are :",percentage)
# Out:
# Enter the marks for subject1 :100
# Enter the marks for subject2 :100
# Enter the marks for subject3 :100
# Enter the marks for subject4 :100
# Enter the marks for subject5 :100
# enter the total marks :500
# Percentage are : 100.0

# %%
##10.Write a Python program to swap two numbers entered by the user without using a third variable.
a = float(input("Enter the value for a :"))
b = float(input("Enter the value for b :"))

# Swap without using a third variable

a,b = b,a

print("After Swapping :")
print("value for a :",a)
print("value for b :",b)
# Out:
# Enter the value for a :15
# Enter the value for b :33
# After Swapping :
# value for a : 33.0
# value for b : 15.0

# %%
## 11.	Take a number as input and check whether it is even or odd.

num = int(input("Enter the Number :"))

if num % 2 ==0:
  print("Num is Even..")
else:
  print("Num is odd..")
# Out:
# Enter the Number :1
# Num is odd..

# %%
##12.	Write a Python program to convert temperature from Celsius to Fahrenheit using the formula: F = (C × 9/5) + 32.

celcius = float(input("Enter the Temprature in celcius :"))

fahrenheit =(celcius * 9/5)+32
print("display Temprature in fahrenheit",fahrenheit)
# Out:
# Enter the Temprature in celcius :40
# display Temprature in fahrenheit 104.0

# %%
##13.	Write a Python program to convert temperature from Fahrenheit to Celsius using the formula: C = (F - 32) × 5/9

fahrenheit = float(input("Enter the temprature in fahrenheit :"))

celcius =(fahrenheit - 32 ) * 5/9
print("display temprature in celcius :",celcius)
# Out:
# Enter the temprature in fahrenheit :104.0
# display temprature in celcius : 40.0

# %%
##14.	Take two numbers as input and find their greatest common divisor (GCD).

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))


while b != 0:
    a, b = b, a % b

print("GCD is:", a)
# Out:
# Enter first number: 12
# Enter second number: 30
# GCD is: 6

# %%
##15. Write a Python program to calculate the simple interest using the formula: SI = (P × R × T) / 100, where P is the principal amount, R is the rate of interest, and T is the time in years.

P = float(input("Enter the principal amount: "))
R = float(input("Enter the rate of interest: "))
T = float(input("Enter the time in years: "))

SI = (P * R * T) / 100

print("The Simple Interest is:", SI)
# Out:
# Enter the principal amount: 20
# Enter the rate of interest: 2
# Enter the time in years: 3
# The Simple Interest is: 1.2

# %%
##16.	Write a Python program to check whether a number is positive, negative, or zero.

num = int(input("Enter the Number :"))

if num>0:
  print("Number is Positive..")
elif num<0:
  print("number is negative..")

else :
  print("number is zero..")
# Out:
# Enter the Number :-1
# number is negative..

# %%
##17.	Write a Python program to find the largest among three numbers entered by the user.
a =int(input("Enter the Number :"))
b =int(input("Enter the Number :"))
c =int(input("Enter the Number :"))

if a>b and a>c:
  print("the largest number is ",a)
if b>a and b>c:
  print("tha largest number is ",b)
else:
  print("the largest number is ",c)
# Out:
# Enter the Number :100
# Enter the Number :20
# Enter the Number :400
# the largest number is  400

# %%
##18.	Take a number as input and check whether it is a multiple of 5.
num = int(input("Enter the Number  :"))

if num % 5==0:
  print(num,"Number is Multiple of 5")
else :
  print(num," is not multiple of 5")
# Out:
# Enter the Number  :32
# 32  is not multiple of 5

# %%
##19.	Write a Python program to calculate the perimeter of a circle using the formula: perimeter = 2 * π * radius.

# %%
##20.	Write a Python program to check whether a number is divisible by both 3 and 5.

num = int(input("Enter the number :"))

if num % 3 == 0 and num % 5 == 0:
  print("number is divisible by both 3 and 5.")

else:
  print("Number is not divisible by both ")
# Out:
# Enter the number :30
# number is divisible by both 3 and 5.
